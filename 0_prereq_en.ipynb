# %% [markdown]
# # Part 0: Prerequisites
#
# Welcome to the SkyPilot tutorial! Before we get started, we will setup some data and other non-SkyPilot related things.
# To tag along this tutorial, alongside SkyPilot dependencies, you need a valid AWS account and access credentials.
#
# Optionally, having the following will help:
# - Any other cloud credentials of your choosing
# - uv, for your python dependencies
#
# The remainder of this notebook will walk you through how to prepare yourself for multi-cloud magic 🚀🚀🚀
#
# As reference, the author of this tutorial has the following setup:
# - A Macbook Pro, M1 Chip (I know... old...)
# - uv
# - AWS and GCP credentials (Unfortunately, I don't have GPU quotas for AWS 🥲)

# %% [markdown]
# ### A Note on Package Managers
# A lot of people love conda! We are fully aware of this, and SkyPilot works perfectly well on conda too!

# %% [markdown]
# ### Checking our AWS account
#
# To check if you have valid credentials, run the script below:

# %%
! scripts/check-aws.sh
# Out:
# 473.16s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Checking AWS credentials...
#
# ✓ AWS CLI is installed
# ✓ AWS credentials are valid
#
# ✅ Perfect! Let's do this 🔥

# %% [markdown]
# For this tutorial, we recommend using **admin** credentials for simplicity. Later on, we will touch base on a minimal credentials setup.

# %% [markdown]
# ### Creating an UV Environment
# We will be using an `uv` environment for this tutorial. If you want a new one, make one with the script below:

# %%
! scripts/create-uv-env.sh
# Out:
# 603.57s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Creating UV environment with Python 3.11...
#
# Creating environment 'sky' with Python 3.11...
# Using CPython 3.11.7 interpreter at: /opt/homebrew/opt/python@3.11/bin/python3.11
# Creating virtual environment at: sky
# Activate with: source sky/bin/activate
#
# ✅ Environment created successfully!
#
# To activate the environment, run:
#   source sky/bin/activate

# %% [markdown]
# ### Let's Download Our Data
# Machine learning is all about data! We will also need some sort of data. SkyPilot primarily runs in the cloud, and we also assume that your data lives in the cloud too. To simulate this, we will be creating a S3 bucket and uploading the IMDb dataset to the S3 bucket.
#
# Remember your bucket name (S3 bucket names must be globally unique), we will need it for the rest of this tutorial.

# %%
! scripts/download-data.sh --bucket <ENTER YOUR BUCKET NAME>

# %% [markdown]
# Perfect! Now we are ready to start!

# %% [markdown]
# ### Citations
# ```
# @InProceedings{maas-EtAl:2011:ACL-HLT2011,
#   author    = {Maas, Andrew L.  and  Daly, Raymond E.  and  Pham, Peter T.  and  Huang, Dan  and  Ng, Andrew Y.  and  Potts, Christopher},
#   title     = {Learning Word Vectors for Sentiment Analysis},
#   booktitle = {Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies},
#   month     = {June},
#   year      = {2011},
#   address   = {Portland, Oregon, USA},
#   publisher = {Association for Computational Linguistics},
#   pages     = {142--150},
#   url       = {http://www.aclweb.org/anthology/P11-1015}
# }
# ```
